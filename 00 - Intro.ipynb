# %% [markdown]
# # 基本用法

# %%
import tensorflow as tf

# 创建一个常量 op, 产生一个 1x2 矩阵. 这个 op 被作为一个节点
# 加到默认图中.
#
# 构造器的返回值代表该常量 op 的返回值.
matrix1 = tf.constant([[3., 3.]])

# 创建另外一个常量 op, 产生一个 2x1 矩阵.
matrix2 = tf.constant([[2.],[2.]])

# 创建一个矩阵乘法 matmul op , 把 'matrix1' 和 'matrix2' 作为输入.
# 返回值 'product' 代表矩阵乘法的结果.
product = tf.matmul(matrix1, matrix2)

# %%
with tf.Session() as sess:
    result = sess.run(product)
    print(result)
# Out:
# [[12.]]

# %%
# 创建一个变量, 初始化为标量 0.
state = tf.get_variable("counter", initializer=0)
# 创建一个 op, 其作用是使 state 增加 1
one = tf.constant(1)
new_value = tf.add(state, one)
update = tf.assign(state, new_value)
# Out:
# WARNING:tensorflow:From D:\MachineLearning\Anaconda\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
# 启动图后, 变量必须先经过`初始化` (init) op 初始化,
# 首先必须增加一个`初始化` op 到图中.
init_op = tf.initialize_all_variables()

# 启动图, 运行 op
with tf.Session() as sess:
  # 运行 'init' op
  sess.run(init_op)
  # 打印 'state' 的初始值
  print(sess.run([state, one]))
  # 运行 op, 更新 'state', 并打印 'state'
  for _ in range(3):
    sess.run(update)
    print(sess.run(state))
# Out:
# [0, 1]
# 1
# 2
# 3

# %%
input1 = tf.placeholder(tf.float32)
input2 = tf.placeholder(tf.float32)
output = tf.multiply(input1, input2)

with tf.Session() as sess:
    result = sess.run(output, feed_dict={input1:[1.,2.,3.], input2:[4.,5.,6.]})
    print(result)
# Out:
# [ 4. 10. 18.]

# %% [markdown]
# # Variable和get_variable的区别

# %%
a = tf.Variable(tf.constant(0.1, shape=[32]))
b = tf.get_variable('b', shape=[32], initializer=tf.constant_initializer(0.1))
# Out:
# WARNING:tensorflow:From D:\MachineLearning\Anaconda\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
init_op = tf.initialize_all_variables()
with tf.Session() as sess:
    sess.run(init_op)
    v = sess.run(a)
    print(v.shape)
    print(v)
    x = sess.run(b)
    print(x.shape)
    print(x)
# Out:
# ERROR:tensorflow:==================================
# Object was never used (type <class 'tensorflow.python.framework.ops.Operation'>):
# <tf.Operation 'init' type=NoOp>
# If you want to mark it as used call its "mark_used()" method.
# It was originally created here:
#   File "D:\MachineLearning\Anaconda\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)  File "D:\MachineLearning\Anaconda\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)  File "D:\MachineLearning\Anaconda\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()  File "D:\MachineLearning\Anaconda\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()  File "D:\MachineLearning\Anaconda\lib\site-packages\ipykernel\kernelapp.py", line 499, in start
#     self.io_loop.start()  File "D:\MachineLearning\Anaconda\lib\site-packages\tornado\platform\asyncio.py", line 132, in start
# ...

# %%
W = tf.Variable(tf.truncated_normal([5, 5, 32, 64], stddev=0.1))
W_conv2 = tf.get_variable('W_conv2', shape=[5, 5, 32, 64], initializer=tf.truncated_normal_initializer)
# Out:
# WARNING:tensorflow:From D:\MachineLearning\Anaconda\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
Y1 = tf.Variable(tf.truncated_normal([1024]， stddev=0.1))
Y2 = tf.get_variable('Y2', shape=[1024], initializer=tf.truncated_normal_initializer(stddev=0.1))

# %%
init_op = tf.initialize_all_variables()
with tf.Session() as sess:
    sess.run(init_op)
    v = sess.run(W)
    print(v.shape)
    print(v)
    x = sess.run(W_conv2)
    print(x.shape)
    print(x)
# Out:
# WARNING:tensorflow:From D:\MachineLearning\Anaconda\lib\site-packages\tensorflow\python\util\tf_should_use.py:193: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# (5, 5, 32, 64)
# [[[[-1.11009024e-01 -1.23655774e-01  7.06765577e-02 ...  2.42378917e-02
#     -2.86156889e-02 -4.69148606e-02]
#    [-1.04909517e-01  1.41826138e-01  1.34564622e-03 ...  8.97408500e-02
#     -1.05396532e-01 -1.29518285e-01]
#    [ 4.47673313e-02  8.37260187e-02 -1.01649247e-01 ...  8.57399330e-02
#     -2.52381116e-02  4.49305028e-02]
#    ...
#    [ 3.12361773e-03  6.58822730e-02  2.64639352e-02 ... -1.77498206e-01
#      4.01918553e-02  1.62955374e-01]
#    [ 2.16120090e-02 -6.27615675e-02  1.17559172e-01 ... -2.15192940e-02
#      1.22916950e-02  5.67787252e-02]
#    [ 2.23548338e-02 -4.40164916e-02  6.89925998e-02 ... -7.37024769e-02
# ...
